# %%
from utils import load_data
from linear_reg import gradient_descent
from linear_reg import compute_gradient
from linear_reg import compute_cost
from public_tests import compute_cost_test
from public_tests import compute_gradient_test
from public_tests import compute_gradient_descent_test
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

#Ej 1
x, y = np.loadtxt('data/ex1data1.txt', delimiter=',', unpack=True)
plt.scatter(x, y)

plt.xlabel('Renta')
plt.ylabel('Beneficio medio')
plt.show()

#Ej 2
compute_cost_test(compute_cost)
#Ej 3
compute_gradient_test(compute_gradient)
#Ej 4
alpha = 0.01
iterations = 1500
w, b, J_history = gradient_descent(x, y, 0, 0, compute_cost, compute_gradient, alpha, iterations)
compute_gradient_descent_test(w, b)

#Ej 5
plt.plot(range(1500), J_history, color = "b")
plt.title("Curva de aprendizaje")
plt.xlabel("Iteración")
plt.ylabel("Coste")
plt.show()

#Ej 6
plt.scatter(x, y)

plt.plot(x[:], w * x[:] + b, color = "r")

plt.xlabel('Renta')
plt.ylabel('Beneficio medio')
plt.show()
# Out:
# Testing: compute_cost_test
# Cost case 1
# Case 1 passed!
# Cost case 2
# Case 2 passed!
# Cost case 3
# Case 3 passed!
# Cost case 4
# Case 4 passed!
# Cost case 5
# Case 5 passed!
# All tests passed!
# Testing: compute_gradient_test
# Using X with shape (4, 1)
# Case 1
# 0.0 0.0
# Case 1 passed!
# Case 2
# Case 2 passed!
# All tests passed!
# Testing: compute_gradient_descent_test
# Case 1
# Case 1 passed!
# Case 2
# Case 2 passed!
# All tests passed!
